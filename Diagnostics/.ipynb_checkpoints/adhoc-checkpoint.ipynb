# %%
### Assumption : Confirmed_cases.csv exists in the working directory

from selenium import webdriver
import pandas as pd
import os
import re
from selenium.webdriver import ActionChains
from selenium.common.exceptions import NoSuchElementException  
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import random
from datetime import datetime
import collections

# %%
URL = "https://www.arcgis.com/apps/opsdashboard/index.html#/85320e2ea5424dfaaa75ae62e5c06e61"

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.headless = True
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)
br = webdriver.Chrome(executable_path=r"C:/Users/qasim/Downloads/chromedriver_win32_v80/chromedriver.exe",options=chrome_options)
br.get(URL)
time.sleep(3)

# %%
data = br.find_element_by_id("ember21").text.split("\n")[:6]

# %%
def extract_num(string):
    string = string.split(" ")[0]
    return int(string.replace(",", ""))

# %%
logistics = {"CONFIRMED" : extract_num(data[1]), "DEATHS" : extract_num(data[3]), "RECOVERED" : extract_num(data[5])}

# %%
data = br.find_element_by_id("ember107").click()

# %%
TIME = str(datetime.now())
TIME = ':'.join(TIME.split(":")[:-1])

# %%
root = br.find_element_by_id("ember60")

# %%
br.find_element_by_id("ember66").screenshot("Images/"+ TIME.split(" ")[0] +".png")
# Out:
# True

# %%
data = root.text.split("\n")[1:100]

# %%
case = {}

# %%
for x in data:
    x = x.split(" ")
    country = " ".join(x[1:]).replace("*", "").strip()
    cases = int(x[0].replace(",",""))
    case[country] = cases

# %%
case = collections.OrderedDict(sorted(case.items()))

# %%
raw_data = {**logistics, **case}

# %%
df = pd.read_csv("Confirmed_case.csv")

# %%
df.head()
# Out:
#        Country  2020-03-18 18:53  2020-03-18 19:07  2020-03-18 19:17  \
# 0    CONFIRMED            214894          214894.0          214894.0
# 1       DEATHS              8732            8732.0            8732.0
# 2    RECOVERED             83313           83313.0           83313.0
# 3  Afghanistan                22              22.0              22.0
# 4      Albania                59              59.0              59.0
#
#    2020-03-18 19:27  2020-03-18 20:09  2020-03-18 20:18  2020-03-18 20:28  \
# 0          214894.0          214894.0          214894.0          214894.0
# 1            8732.0            8732.0            8732.0            8732.0
# 2           83313.0           83313.0           83313.0           83313.0
# 3              22.0              22.0              22.0              22.0
# 4              59.0              59.0              59.0              59.0
#
#    2020-03-18 20:57  2020-03-18 21:07  ...  2020-03-19 02:27  \
# 0          214894.0          214894.0  ...          218815.0
# 1            8732.0            8732.0  ...            8810.0
# 2           83313.0           83323.0  ...           84114.0
# 3              22.0              22.0  ...              22.0
# 4              59.0              59.0  ...              59.0
#
#    2020-03-19 02:37  2020-03-19 02:47  2020-03-19 02:57  2020-03-19 03:07  \
# 0          218815.0          218815.0          218815.0          218823.0
# 1            8810.0            8810.0            8810.0            8810.0
# 2           84114.0           84114.0           84118.0           84118.0
# 3              22.0              22.0              22.0              22.0
# 4              59.0              59.0              59.0              59.0
#
#    2020-03-19 03:17  2020-03-19 03:27  2020-03-19 03:37  2020-03-19 03:47  \
# 0          218823.0          218824.0          218824.0          218824.0
# 1            8810.0            8810.0            8810.0            8810.0
# 2           84118.0           84118.0           84118.0           84118.0
# 3              22.0              22.0              22.0              22.0
# 4              59.0              59.0              59.0              59.0
#
#    2020-03-19 03:57
# 0          218824.0
# 1            8810.0
# 2           84118.0
# 3              22.0
# 4              59.0
#
# [5 rows x 51 columns]

# %%
conts = list(df["Country"])
curr_count = len(df["Country"])

# %%
zero_fill = np.zeros(df.shape[1] - 1)

# %%
for label in raw_data:
    if(label not in conts):
        temp = np.append(zero_fill, label)
        temp = temp[::-1]
        df.loc[curr_count] = temp

# %%
df.tail()
# Out:
#                   Country  2020-03-18 18:53  2020-03-18 19:07  \
# 97   United Arab Emirates               113             113.0
# 98         United Kingdom              2642            2642.0
# 99                Uruguay                50              50.0
# 100             Venezuela                36              36.0
# 101               Vietnam                75              75.0
#
#      2020-03-18 19:17  2020-03-18 19:27  2020-03-18 20:09  2020-03-18 20:18  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-18 20:28  2020-03-18 20:57  2020-03-18 21:07  ...  \
# 97              113.0             113.0             113.0  ...
# 98             2642.0            2642.0            2642.0  ...
# 99               50.0              50.0              50.0  ...
# 100              36.0              36.0              36.0  ...
# 101              75.0              75.0              75.0  ...
#
#      2020-03-19 02:27  2020-03-19 02:37  2020-03-19 02:47  2020-03-19 02:57  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:07  2020-03-19 03:17  2020-03-19 03:27  2020-03-19 03:37  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:47  2020-03-19 03:57
# 97              113.0             113.0
# 98             2642.0            2642.0
# 99               50.0              50.0
# 100              36.0              36.0
# 101              75.0              75.0
#
# [5 rows x 51 columns]

# %%
df_temp = pd.DataFrame.from_dict(raw_data, orient="index", columns=[TIME]).reset_index()

# %%
del df_temp["index"]

# %%
df_cum = [df, df_temp]

# %%
df_cum = pd.concat(df_cum, axis=1)

# %%
df_cum.tail()
# Out:
#                   Country  2020-03-18 18:53  2020-03-18 19:07  \
# 97   United Arab Emirates               113             113.0
# 98         United Kingdom              2642            2642.0
# 99                Uruguay                50              50.0
# 100             Venezuela                36              36.0
# 101               Vietnam                75              75.0
#
#      2020-03-18 19:17  2020-03-18 19:27  2020-03-18 20:09  2020-03-18 20:18  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-18 20:28  2020-03-18 20:57  2020-03-18 21:07  ...  \
# 97              113.0             113.0             113.0  ...
# 98             2642.0            2642.0            2642.0  ...
# 99               50.0              50.0              50.0  ...
# 100              36.0              36.0              36.0  ...
# 101              75.0              75.0              75.0  ...
#
#      2020-03-19 02:37  2020-03-19 02:47  2020-03-19 02:57  2020-03-19 03:07  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:17  2020-03-19 03:27  2020-03-19 03:37  2020-03-19 03:47  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:57  2020-03-19 03:59
# 97              113.0               113
# 98             2642.0              2644
# 99               50.0                79
# 100              36.0                36
# 101              75.0                75
#
# [5 rows x 52 columns]

# %%
null_values = df_cum[df_cum[TIME].isnull()].index.tolist()

# %%
if(len(null_values) > 0):
    priori = df_cum.columns[-2]
    df_copy = df_cum.copy()

    for x in null_values:
        value = df_copy[priori][x]
        df_cum.loc[:,TIME][x] = value

    del df_copy

# %%
df_cum
# Out:
#                   Country  2020-03-18 18:53  2020-03-18 19:07  \
# 97   United Arab Emirates               113             113.0
# 98         United Kingdom              2642            2642.0
# 99                Uruguay                50              50.0
# 100             Venezuela                36              36.0
# 101               Vietnam                75              75.0
#
#      2020-03-18 19:17  2020-03-18 19:27  2020-03-18 20:09  2020-03-18 20:18  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-18 20:28  2020-03-18 20:57  2020-03-18 21:07  ...  \
# 97              113.0             113.0             113.0  ...
# 98             2642.0            2642.0            2642.0  ...
# 99               50.0              50.0              50.0  ...
# 100              36.0              36.0              36.0  ...
# 101              75.0              75.0              75.0  ...
#
#      2020-03-19 02:37  2020-03-19 02:47  2020-03-19 02:57  2020-03-19 03:07  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:17  2020-03-19 03:27  2020-03-19 03:37  2020-03-19 03:47  \
# 97              113.0             113.0             113.0             113.0
# 98             2642.0            2642.0            2642.0            2642.0
# 99               50.0              50.0              50.0              50.0
# 100              36.0              36.0              36.0              36.0
# 101              75.0              75.0              75.0              75.0
#
#      2020-03-19 03:57  2020-03-19 03:59
# 97              113.0               113
# 98             2642.0              2644
# 99               50.0                79
# 100              36.0                36
# 101              75.0                75
#
# [5 rows x 52 columns]

# %%
df_cum.to_csv("Confirmed_case.csv", index=False)
